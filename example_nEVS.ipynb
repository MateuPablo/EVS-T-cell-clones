# %% [markdown]
# # Extreme Value Statistics of T cell clones with normalised frequency sum

# %% [markdown]
# This code is an example on how to use the file 'EVS_functions.py' in order to fit the normalised non-mixed EVS functions to the Emerson top clone data.
#
# The notebook contains:
# 1. Definition of the integral
# 2. Fit to data

# %% [markdown]
# ## Imports

# %% [markdown]
# - _numpy_ for math operations
# - _matplotlib_ for graphic representations
# - _pandas_ for operations with DataFrames
# - _time_ to calculate the fitting time
# - _scipy_ for integration
# - _EVS_functions_ for the PDF and CDF functions from the normalised EVS
# - _multiprocessing_ to boost the fitting and multiple-point evaluations of the functions
# - _lmfit_ for non-linear least squares fitting

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import pandas as pd
import time
from scipy.integrate import quad
from scipy.integrate import fixed_quad
from EVS_functions import g_n
from multiprocessing import Pool
from lmfit import Model, Parameters

# %% [markdown]
# ## Loading data

# %% [markdown]
# To load the clone data, the user needs:
#
# - top_1_clones_Emerson : file containing the data for the top clones of the whole Emerson cohort
#
# The notebook and the 'top_1_clones_Emerson' file need to be in the same path. Otherwise, it is necessary to specify the path

# %%
top_clones_file = 'top_1_clones_Emerson'  # change the name of file if necessary

fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (10, 3.2))

top_clones = pd.read_csv(top_clones_file)
top_clones['x'] = np.log10(top_clones['m'])

interval = np.linspace(top_clones['x'].min(), top_clones['x'].max(), 20)

peaks_r, edges_r, patches_r = ax1.hist(top_clones['x'], bins = interval,  # creating the density distribution
                                       density=True, fill=None, histtype='step', 
                                       color = 'blue', label = 'top clones data', lw=2) 
centers_r = np.array([(edges_r[i] + edges_r[i + 1]) / 2 for i in range(len(edges_r) - 1)])

ax1.plot(centers_r, peaks_r, 'o', color = 'black', label = 'fitting points')
ax1.legend()
ax1.set_xlabel(r'$\log_{10}(m)$')
ax1.set_ylabel('Density distribution')

ax2.hist(top_clones['m'], bins = 200, density = True, fill = None, histtype = 'step',
        color = 'blue', label = 'top clones data', lw = 2)
ax2.legend()
ax2.set_xlabel(r'm')
ax2.set_ylabel('Density distribution')
ax2.set_xlim([-0.005,0.1])
# Out:
# (-0.005, 0.1)

# %% [markdown]
# ## 1. Definition of the integral

# %% [markdown]
# The function 'g_n' from 'EVS_functions' is the normalised PDF distribution
#
# Multiprocessing makes the evaluation at multiple points faster

# %%
g_n
# Out:
# <function EVS_functions.g_n(x, z, y)>

# %%
def g_n_multiprocess(x, z, y):
    args = [(x_i, z, y) for x_i in x]
    if __name__ == '__main__':
        with Pool(6) as p:  # 6 is the optimal number of cpu to use. My computer has 8. A good rule is n_cpu-2
            g_n_result = p.starmap(g_n, args)
    return g_n_result

# %% [markdown]
# ## 2. Fit to data

# %% [markdown]
# ### A. Fitting model and parameters

# %%
model = Model(g_n_multiprocess)  # fitting model

z0 = np.log10(0.5)  # initial conditions for the parameters
y0 = -9

par = Parameters()  # definition of the parameters
par.add('z', value = z0, min = -1, max = 0)
par.add('y', value = y0, min = -13, max = -6)

peaks_fit = peaks_r  # data points for the fit
centers_fit = centers_r

# %% [markdown]
# ### B. Fitting procedure

# %% [markdown]
# #### 1. Execution of the fit

# %%
time_ini = time.time()

res = model.fit(peaks_fit, x = centers_fit, z = par['z'], y = par['y'])  # fit

time_fin = time.time()
time_tot = (time_fin-time_ini)/60
print('Execution time: '+str(time_tot) + ' minutes')  # fitting time
# Out:
# Execution time: 2.9765319228172302 minutes

# %% [markdown]
# #### 2. Returned parameters and statistical analysis

# %%
z_opt = res.params['z'].value  # optimal parameters
y_opt = res.params['y'].value

f_min_opt = 10**y_opt
alpha_opt = 1+10**z_opt

print('Optimal values:\n\t a0 = '+str("%.2f"%alpha_opt)+'\n\t fm = '+str("%.2e"%f_min_opt))

res  # statistical analysis of the fit
# Out:
# Optimal values:
# 	 a0 = 1.15
# 	 fm = 3.02e-13
# <h2> Model</h2> Model(g_n_multiprocess) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>39</td><td></td></tr><tr><td># data points</td><td>19</td><td></td></tr><tr><td># variables</td><td>2</td><td></td></tr><tr><td>chi-square</td><td> 1.26910762</td><td></td></tr><tr><td>reduced chi-square</td><td> 0.07465339</td><td></td></tr><tr><td>Akaike info crit.</td><td>-47.4163748</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-45.5274969</td><td></td></tr><tr><td>R-squared</td><td> 0.17928485</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> z </td><td> -0.82160627 </td><td>  0.02289526 </td><td> (2.79%) </td><td> -0.3010299956639812 </td><td> -1.00000000 </td><td>  0.00000000 </td><td> True </td></tr><tr><td> y </td><td> -12.5194365 </td><td>  0.05678130 </td><td> (0.45%) </td><td> -9 </td><td> -13.0000000 </td><td> -6.00000000 </td><td> True </td></tr></table>

# %% [markdown]
# #### 3. Representation

# %%
m_plot = np.logspace(np.log10(top_clones['m'].min()), np.log10(top_clones['m'].max()), 75)  # creating the axis
x_plot = np.linspace(top_clones['x'].min(), top_clones['x'].max(), 75) 
PDF_plot = g_n_multiprocess(x_plot, z_opt, y_opt)/(np.log(10)*m_plot)

plt.hist(top_clones['m'], bins = 200, density = True, fill = None, histtype = 'step',
        color = 'dodgerblue', label = 'top clones data', lw = 2)
plt.plot(m_plot, PDF_plot, label = r'optimal curve', color = 'black', lw = 2)

plt.xlim(-0.005, 0.1)
plt.ylim(0,60)
plt.legend(loc = 'upper right')
plt.xlabel('Top clone frequency')
plt.ylabel('Density distribution')
# Out:
# Text(0, 0.5, 'Density distribution')
